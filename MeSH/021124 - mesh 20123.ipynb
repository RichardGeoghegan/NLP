# %%
from xml.etree import cElementTree as elemtree
from datetime import date

"""
Use this to parse XML from MeSH (Medical Subject Headings). More information 
on the format at: http://www.ncbi.nlm.nih.gov/mesh
End users will primarily want to call the `parse_mesh` function and do something
with the output.
"""

def parse_mesh(filename):
    """Parse a mesh file, successively generating
    `DescriptorRecord` instance for subsequent processing."""
    for _evt, elem in elemtree.iterparse(filename):
        if elem.tag == 'DescriptorRecord':
            yield DescriptorRecord.from_xml_elem(elem)

def date_from_mesh_xml(xml_elem):
    year = xml_elem.find('./Year').text
    month = xml_elem.find('./Month').text
    day = xml_elem.find('./Day').text
    return date(int(year), int(month), int(day))

class PharmacologicalAction(object):
    """A pharmacological action, denoting the effects of a MeSH descriptor."""
    
    def __init__(self, descriptor_ui):
        self.descriptor_ui = descriptor_ui
    
    @classmethod
    def from_xml_elem(cls, elem):
        descriptor_ui = elem.find('./DescriptorReferredTo/DescriptorUI')
        return cls(descriptor_ui)

class SlotsToNoneMixin(object):
    def __init__(self, **kwargs):
        for attr in self.__slots__:
            setattr(self, attr, kwargs.get(attr, None))
    
    def __repr__(self):
        attrib_repr = ', '.join(u'%s=%r' % (attr, getattr(self, attr)) for attr in self.__slots__)
        return self.__class__.__name__ + '(' + attrib_repr + ')'

class Term(SlotsToNoneMixin):
    """A term from within a MeSH concept."""

    __slots__ = ('term_ui', 'string', 'is_concept_preferred', 'is_record_preferred',
      'is_permuted', 'lexical_tag', 'date_created', 'thesaurus_list')
    
    @classmethod
    def from_xml_elem(cls, elem):
        term = cls()
        term.is_concept_preferred = elem.get('ConceptPreferredTermYN', None) == 'Y'
        term.is_record_preferred = elem.get('RecordPreferredTermYN', None) == 'Y'
        term.is_permuted = elem.get('IsPermutedTermYN', None) == 'Y'
        term.lexical_tag = elem.get('LexicalTag')
        for child_elem in elem:
            if child_elem.tag == 'TermUI':
                term.term_ui = child_elem.text
            elif child_elem.tag == 'String':
                term.string = child_elem.text
                #term.name = [th_elem.text for th_elem in child_elem]
            elif child_elem.tag == 'DateCreated':
                term.date_created = date_from_mesh_xml(child_elem)
            elif child_elem.tag == 'ThesaurusIDlist':
                term.thesaurus_list = [th_elem.text for th_elem in child_elem]
        return term

class SemanticType(SlotsToNoneMixin):
    __slots__ = ('ui', 'name')
    
    @classmethod
    def from_xml_elem(cls, elem):
        sem_type = cls()
        for child_elem in elem:
            if child_elem.tag == 'SemanticTypeUI':
                sem_type.ui = child_elem.text
            elif child_elem.tag == 'SemanticTypeName':
                sem_type.name = child_elem.text

class Concept(SlotsToNoneMixin):
    """A concept within a MeSH Descriptor."""
    __slots__ = ( 'ui', 'name', 'is_preferred', 'umls_ui', 'casn1_name', 'registry_num', 
      'scope_note', 'sem_types', 'terms')
    
    @classmethod
    def from_xml_elem(cls, elem):
        concept = cls()
        concept.is_preferred = elem.get('PreferredConceptYN', None) == 'Y'
        for child_elem in elem:
            if child_elem.tag == 'ConceptUI':
                concept.ui = child_elem.text
            elif child_elem.tag == 'ConceptName':
                concept.name = child_elem.find('./String').text
            elif child_elem.tag == 'ConceptUMLSUI':
                concept.umls_ui
            elif child_elem.tag == 'CASN1Name':
                concept.casn1_name = child_elem.text
            elif child_elem.tag == 'RegistryNumber':
                concept.registry_num = child_elem.text
            elif child_elem.tag == 'ScopeNote':
                concept.scope_note = child_elem.text
            elif child_elem.tag == 'SemanticTypeList':
                concept.sem_types = [SemanticType.from_xml_elem(st_elem)
                  for st_elem in child_elem.findall('SemanticType')]
            elif child_elem.tag == 'TermList':
                concept.terms = [Term.from_xml_elem(term_elem)
                  for term_elem in child_elem.findall('Term')]
        return concept

class DescriptorRecord(SlotsToNoneMixin):
    "A MeSH Descriptor Record."""
    
    __slots__ = ('ui', 'name', 'date_created', 'date_revised', 'pharm_actions', 
      'tree_numbers', 'concepts')
    
    @classmethod
    def from_xml_elem(cls, elem):
        rec = cls()
        for child_elem in elem:
            if child_elem.tag == 'DescriptorUI':
                rec.ui = child_elem.text
            elif child_elem.tag == 'DescriptorName':
                rec.name = child_elem.find('./String').text
            elif child_elem.tag == 'DateCreated':
                rec.date_created = date_from_mesh_xml(child_elem)
            elif child_elem.tag == 'DateRevised':
                rec.date_revised = date_from_mesh_xml(child_elem)
            elif child_elem.tag == 'TreeNumberList':
                rec.tree_numbers = [tn_elem.text
                  for tn_elem in child_elem.findall('TreeNumber')]
            elif child_elem.tag == 'ConceptList':
                rec.concepts = [Concept.from_xml_elem(c_elem) 
                  for c_elem in child_elem.findall('Concept')]
            elif child_elem.tag == 'PharmacologicalActionList':
                rec.pharm_actions = [PharmacologicalAction.from_xml_elem(pa_elem) 
                  for pa_elem in child_elem.findall('PharmacologicalAction')]
        return rec

# %%
#data=parse_mesh('C:\\Users\\Richard.Geoghegan\\Documents\\mdm_db\\edw\\dev\\input\\desc2017.xml')
data=parse_mesh('C:\\Users\\Richard.Geoghegan\\Downloads\\desc2023.xml')
#D002292=[item for item in data if item.ui=='D002292']

# %%
curr=next(data)
curr
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-32-1ce32cc94872> in <module>
# ----> 1 curr=next(data)
#       2 curr
#
# StopIteration:

# %%
#counter=1
curr=[next(data)]

def xml_to_list(counter):
    try:
        while True:
            counter +=1
            if (counter % 1000==0):
                print('Progress report...', counter, )
                
            curr=[next(data)]
    except StopIteration:
        pass
    finally:
        return counter

count=xml_to_list(0)
count
# Out:
# Progress report... 1000
# Progress report... 2000
# Progress report... 3000
# Progress report... 4000
# Progress report... 5000
# Progress report... 6000
# Progress report... 7000
# Progress report... 8000
# Progress report... 9000
# Progress report... 10000
# Progress report... 11000
# Progress report... 12000
# Progress report... 13000
# Progress report... 14000
# Progress report... 15000
# Progress report... 16000
# Progress report... 17000
# Progress report... 18000
# Progress report... 19000
# Progress report... 20000
# Progress report... 21000
# Progress report... 22000
# Progress report... 23000
# Progress report... 24000
# Progress report... 25000
# Progress report... 26000
# Progress report... 27000
# Progress report... 28000
# Progress report... 29000
# Progress report... 30000
# 30452

# %%
#curr=[next(data)]
#curr
ui, name, conc = [[item.ui, item.name, item.concepts, item.tree_numbers or 'EMPTY'] for item in curr ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-843bbad4c23a> in <module>
#       1 #curr=[next(data)]
#       2 #curr
# ----> 3 ui, name, conc = [[item.ui, item.name, item.concepts, item.tree_numbers or 'EMPTY'] for item in curr ]
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
treetops = ['F','C']
data=parse_mesh('C:\\Users\\Richard.Geoghegan\\Downloads\\desc2023.xml')

res=[]
#curr=[next(data)]

def xml_to_list(counter):
    try:
        while True:
            curr=[next(data)]
            counter +=1
            #ui, name, conc = [[item.ui, item.name, item.concepts, item.tree_numbers or 'EMPTY'] for item in curr ][0]
            for i, val in enumerate([[item.ui, item.name, item.concepts, item.tree_numbers] 
                                     for item in curr 
                                     if any(s for s in str(item.tree_numbers or 'EMPTY') if any(xs in s for xs in treetops))]):
                #print('start: ', i, conc)
                ui=val[0]
                #print(ui)
                name=val[1]
                conc=val[2]
                #print(conc)
                #tree=val[2]
                tree = [item for item in val[3] if any(s for s in item if any(xs in s for xs in treetops))]
                #top = min([s.split('.')[0] for s in tree])
                top = list(set(item.split('.')[0] for item in tree))
                #print(top)
                for j in range(len(conc)):
                    #print('next: ',i,j)
                    for k in range(len(conc[j].terms)):
                        #print(i,j,k)
                        #print(counter, top, ui, name, conc[j].terms[k].term_ui, conc[j].terms[k].string )
                        res.append([top, ui, name, conc[j].terms[k].term_ui, conc[j].terms[k].string])
                        #curr=[next(data)]
                        if (counter % 1000==0):
                            print('Progress report...', counter, i,j,k)
    except StopIteration:
        print(ui)
        print(name)
        print(conc)
        print(tree)
        print(top)
        pass
    finally:
        return res

res=xml_to_list(0)

import csv
import os

data_dir = 'C:\\Users\\Richard.Geoghegan\\Documents\\NLP\\MeSH'
data_file='mesh_terms_treetop_test'
data_file = os.path.join(data_dir, data_file+'.csv')
data_file

with open(data_file, 'w', newline='') as f:
    wr = csv.writer(f, delimiter ='|')
    wr.writerows(res)
# Out:
# Progress report... 5000 0 0 0
# Progress report... 5000 0 0 1
# Progress report... 5000 0 0 2
# Progress report... 5000 0 0 3
# Progress report... 5000 0 0 4
# Progress report... 5000 0 0 5
# Progress report... 5000 0 0 6
# Progress report... 5000 0 0 7
# Progress report... 5000 0 0 8
# Progress report... 5000 0 0 9
# Progress report... 5000 0 1 0
# Progress report... 5000 0 1 1
# Progress report... 5000 0 1 2
# Progress report... 5000 0 1 3
# Progress report... 5000 0 1 4
# Progress report... 5000 0 1 5
# Progress report... 5000 0 1 6
# Progress report... 5000 0 2 0
# Progress report... 5000 0 2 1
# Progress report... 5000 0 2 2
# Progress report... 5000 0 2 3
# Progress report... 5000 0 2 4
# Progress report... 5000 0 2 5
# Progress report... 5000 0 2 6
# Progress report... 5000 0 3 0
# Progress report... 5000 0 3 1
# Progress report... 5000 0 3 2
# Progress report... 5000 0 3 3
# Progress report... 5000 0 3 4
# Progress report... 5000 0 3 5
# Progress report... 5000 0 4 0
# Progress report... 5000 0 4 1
# Progress report... 5000 0 4 2
# Progress report... 5000 0 4 3
# Progress report... 5000 0 4 4
# Progress report... 5000 0 4 5
# Progress report... 5000 0 5 0
# Progress report... 5000 0 5 1
# Progress report... 5000 0 5 2
# Progress report... 5000 0 5 3
# Progress report... 8000 0 0 0
# Progress report... 8000 0 0 1
# Progress report... 8000 0 0 2
# Progress report... 8000 0 0 3
# Progress report... 8000 0 0 4
# Progress report... 8000 0 0 5
# Progress report... 8000 0 0 6
# Progress report... 8000 0 0 7
# Progress report... 8000 0 0 8
# Progress report... 8000 0 0 9
# Progress report... 8000 0 0 10
# Progress report... 8000 0 0 11
# Progress report... 8000 0 0 12
# Progress report... 8000 0 0 13
# Progress report... 8000 0 0 14
# Progress report... 8000 0 0 15
# Progress report... 8000 0 0 16
# Progress report... 8000 0 0 17
# Progress report... 8000 0 0 18
# Progress report... 8000 0 0 19
# Progress report... 8000 0 0 20
# Progress report... 8000 0 0 21
# Progress report... 8000 0 0 22
# Progress report... 8000 0 0 23
# Progress report... 8000 0 0 24
# Progress report... 12000 0 0 0
# Progress report... 12000 0 0 1
# Progress report... 12000 0 0 2
# Progress report... 12000 0 0 3
# Progress report... 12000 0 0 4
# Progress report... 12000 0 0 5
# Progress report... 12000 0 0 6
# Progress report... 12000 0 0 7
# Progress report... 12000 0 0 8
# Progress report... 12000 0 0 9
# Progress report... 12000 0 0 10
# Progress report... 12000 0 0 11
# Progress report... 16000 0 0 0
# Progress report... 16000 0 0 1
# Progress report... 16000 0 0 2
# D066279
# Courage
# [Concept(ui='M0593634', name='Courage', is_preferred=True, umls_ui=None, casn1_name=None, registry_num=None, scope_note='State of mind or spirit that enables one to act in the face of perceived danger, difficulty, or pain.\n    ', sem_types=None, terms=[Term(term_ui='T858670', string='Courage', is_concept_preferred=True, is_record_preferred=True, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2014, 4, 18), thesaurus_list=['NLM (2015)']), Term(term_ui='T858672', string='Heroism', is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2014, 4, 18), thesaurus_list=['NLM (2015)']), Term(term_ui='T858671', string='Bravery', is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2014, 4, 18), thesaurus_list=['NLM (2015)'])])]
# ['F01.470.257']
# ['F01']

# %%
#Glioblastoma
#[item for item in res if item[1]=='D005909']
#Non-alcoholic Fatty Liver Disease
[item for item in res if item[1]=='D065626']
# Out:
# [[['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747320',
#   'Non-alcoholic Fatty Liver Disease'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747320',
#   'Non alcoholic Fatty Liver Disease'],
#  [['C06'], 'D065626', 'Non-alcoholic Fatty Liver Disease', 'T747417', 'NAFLD'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747319',
#   'Nonalcoholic Fatty Liver Disease'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747321',
#   'Fatty Liver, Nonalcoholic'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747321',
#   'Fatty Livers, Nonalcoholic'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747321',
#   'Liver, Nonalcoholic Fatty'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747321',
#   'Livers, Nonalcoholic Fatty'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747321',
#   'Nonalcoholic Fatty Liver'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T747321',
#   'Nonalcoholic Fatty Livers'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T853030',
#   'Nonalcoholic Steatohepatitis'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T853030',
#   'Nonalcoholic Steatohepatitides'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T853030',
#   'Steatohepatitides, Nonalcoholic'],
#  [['C06'],
#   'D065626',
#   'Non-alcoholic Fatty Liver Disease',
#   'T853030',
#   'Steatohepatitis, Nonalcoholic']]

# %%
ui, name, conc = [[item.ui, item.name, item.concepts, item.tree_numbers or 'EMPTY'] for item in next(data) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f40c502e572c> in <module>
# ----> 1 ui, name, conc = [[item.ui, item.name, item.concepts, item.tree_numbers or 'EMPTY'] for item in next(data) ]
#
# NameError: name 'data' is not defined

# %%
[item[-1].replace(',','').split() for item in res if item[1]=='D000163']
# Out:
# [['Acquired', 'Immunodeficiency', 'Syndrome'],
#  ['Immunologic', 'Deficiency', 'Syndrome', 'Acquired'],
#  ['Acquired', 'Immune', 'Deficiency', 'Syndrome'],
#  ['Acquired', 'Immuno-Deficiency', 'Syndrome'],
#  ['Acquired', 'Immuno', 'Deficiency', 'Syndrome'],
#  ['Acquired', 'Immuno-Deficiency', 'Syndromes'],
#  ['Immuno-Deficiency', 'Syndrome', 'Acquired'],
#  ['Immuno-Deficiency', 'Syndromes', 'Acquired'],
#  ['Syndrome', 'Acquired', 'Immuno-Deficiency'],
#  ['Syndromes', 'Acquired', 'Immuno-Deficiency'],
#  ['Immunodeficiency', 'Syndrome', 'Acquired'],
#  ['Acquired', 'Immunodeficiency', 'Syndromes'],
#  ['Immunodeficiency', 'Syndromes', 'Acquired'],
#  ['Syndrome', 'Acquired', 'Immunodeficiency'],
#  ['Syndromes', 'Acquired', 'Immunodeficiency'],
#  ['AIDS']]

# %%
xss=[item[-1].replace(',','').split() for item in res if item[1]=='D002292']
list(set().union(*xss))
# Out:
# ['Collecting',
#  'Nephroid',
#  'Tumor',
#  'Duct',
#  'Hypernephroid',
#  'Cell',
#  'Kidneys',
#  'the',
#  'Renal',
#  'Sarcomatoid',
#  'Kidney',
#  'Chromophil',
#  'Adenocarcinoma',
#  'Carcinomas',
#  'Hypernephromas',
#  'of',
#  'Carcinoma',
#  'Chromophobe',
#  'Of',
#  'Clear',
#  'Cancers',
#  'Adenocarcinomas',
#  'Cancer',
#  '(Kidney)',
#  'Grawitz',
#  'Papillary',
#  'Hypernephroma']

# %%
dict = {}
for elem in res:
    if elem[1] not in dict:
        dict[elem[1]] = ''
    dict[elem[1]].append(elem[2:])

dict

#for key in dict:
#  dict[key] = [sum(i) for i in zip(*dict[key])]
# Out:
# {'D000006': [['Abdomen, Acute', 'T000013', 'Abdomen, Acute'],
#   ['Abdomen, Acute', 'T000013', 'Abdomens, Acute'],
#   ['Abdomen, Acute', 'T000013', 'Acute Abdomen'],
#   ['Abdomen, Acute', 'T000013', 'Acute Abdomens']],
#  'D000007': [['Abdominal Injuries', 'T000015', 'Abdominal Injuries'],
#   ['Abdominal Injuries', 'T000014', 'Injuries, Abdominal'],
#   ['Abdominal Injuries', 'T000014', 'Abdominal Injury'],
#   ['Abdominal Injuries', 'T000014', 'Injury, Abdominal']],
#  'D000008': [['Abdominal Neoplasms', 'T000016', 'Abdominal Neoplasms'],
#   ['Abdominal Neoplasms', 'T000016', 'Abdominal Neoplasm'],
#   ['Abdominal Neoplasms', 'T000016', 'Neoplasm, Abdominal'],
#   ['Abdominal Neoplasms', 'T000016', 'Neoplasms, Abdominal']],
#  'D000012': [['Abetalipoproteinemia', 'T000024', 'Abetalipoproteinemia'],
#   ['Abetalipoproteinemia',
#    'T365903',
#    'Microsomal Triglyceride Transfer Protein Deficiency Disease'],
#   ['Abetalipoproteinemia', 'T811395', 'Acanthocytosis'],
#   ['Abetalipoproteinemia', 'T811395', 'Acanthocytoses'],
#   ['Abetalipoproteinemia',
#    'T646365',
#    'Microsomal Triglyceride Transfer Protein Deficiency'],
#   ['Abetalipoproteinemia', 'T751239', 'Betalipoprotein Deficiency Disease'],
#   ['Abetalipoproteinemia', 'T751239', 'Betalipoprotein Deficiency Diseases'],
#   ['Abetalipoproteinemia', 'T751239', 'Deficiency Disease, Betalipoprotein'],
#   ['Abetalipoproteinemia', 'T751239', 'Deficiency Diseases, Betalipoprotein'],
#   ['Abetalipoproteinemia', 'T751239', 'Disease, Betalipoprotein Deficiency'],
#   ['Abetalipoproteinemia', 'T751239', 'Diseases, Betalipoprotein Deficiency'],
#   ['Abetalipoproteinemia', 'T000025', 'Bassen-Kornzweig Syndrome'],
#   ['Abetalipoproteinemia', 'T000025', 'Bassen Kornzweig Syndrome'],
#   ['Abetalipoproteinemia', 'T365904', 'Bassen-Kornzweig Disease'],
#   ['Abetalipoproteinemia', 'T365904', 'Bassen Kornzweig Disease']],
#  'D000013': [['Congenital Abnormalities',
#    'T000029',
#    'Congenital Abnormalities'],
#   ['Congenital Abnormalities', 'T000029', 'Abnormality, Congenital'],
#   ['Congenital Abnormalities', 'T000029', 'Congenital Abnormality'],
#   ['Congenital Abnormalities', 'T000032', 'Deformities'],
#   ['Congenital Abnormalities', 'T000032', 'Deformity'],
#   ['Congenital Abnormalities', 'T000031', 'Congenital Defects'],
#   ['Congenital Abnormalities', 'T000031', 'Congenital Defect'],
#   ['Congenital Abnormalities', 'T000031', 'Defect, Congenital'],
#   ['Congenital Abnormalities', 'T000030', 'Defects, Congenital'],
#   ['Congenital Abnormalities', 'T000028', 'Abnormalities, Congenital'],
#   ['Congenital Abnormalities', 'T000027', 'Birth Defects'],
#   ['Congenital Abnormalities', 'T000027', 'Birth Defect'],
#   ['Congenital Abnormalities', 'T000027', 'Defect, Birth'],
#   ['Congenital Abnormalities', 'T000999312', 'Fetal Malformations'],
#   ['Congenital Abnormalities', 'T000999312', 'Fetal Malformation'],
#   ['Congenital Abnormalities', 'T000999312', 'Malformation, Fetal'],
#   ['Congenital Abnormalities', 'T000999311', 'Fetal Anomalies'],
#   ['Congenital Abnormalities', 'T000999311', 'Anomaly, Fetal'],
#   ['Congenital Abnormalities', 'T000999311', 'Fetal Anomaly']],
#  'D000014': [['Abnormalities, Drug-Induced',
#    'T000034',
#    'Abnormalities, Drug-Induced'],
#   ['Abnormalities, Drug-Induced', 'T000034', 'Abnormalities, Drug Induced'],
#   ['Abnormalities, Drug-Induced', 'T000033', 'Drug-Induced Abnormalities'],
#   ['Abnormalities, Drug-Induced', 'T000033', 'Abnormality, Drug-Induced'],
#   ['Abnormalities, Drug-Induced', 'T000033', 'Drug Induced Abnormalities'],
#   ['Abnormalities, Drug-Induced', 'T000033', 'Drug-Induced Abnormality']],
#  'D000015': [['Abnormalities, Multiple', 'T000036', 'Abnormalities, Multiple'],
#   ['Abnormalities, Multiple', 'T000035', 'Multiple Abnormalities']],
#  'D000016': [['Abnormalities, Radiation-Induced',
#    'T000038',
#    'Abnormalities, Radiation-Induced'],
#   ['Abnormalities, Radiation-Induced',
#    'T000038',
#    'Abnormalities, Radiation Induced'],
#   ['Abnormalities, Radiation-Induced',
#    'T000037',
#    'Radiation-Induced Abnormalities'],
#   ['Abnormalities, Radiation-Induced',
#    'T000037',
#    'Abnormality, Radiation-Induced'],
#   ['Abnormalities, Radiation-Induced',
#    'T000037',
#    'Radiation Induced Abnormalities'],
#   ['Abnormalities, Radiation-Induced',
#    'T000037',
#    'Radiation-Induced Abnormality']],
#  'D000022': [['Abortion, Spontaneous', 'T000053', 'Abortion, Spontaneous'],
#   ['Abortion, Spontaneous', 'T000053', 'Abortions, Spontaneous'],
#   ['Abortion, Spontaneous', 'T000053', 'Spontaneous Abortions'],
#   ['Abortion, Spontaneous', 'T484312', 'Spontaneous Abortion'],
#   ['Abortion, Spontaneous', 'T000937143', 'Early Pregnancy Loss'],
#   ['Abortion, Spontaneous', 'T000937143', 'Early Pregnancy Losses'],
#   ['Abortion, Spontaneous', 'T000937143', 'Loss, Early Pregnancy'],
#   ['Abortion, Spontaneous', 'T000937143', 'Losses, Early Pregnancy'],
#   ['Abortion, Spontaneous', 'T000937143', 'Pregnancy Loss, Early'],
#   ['Abortion, Spontaneous', 'T000937143', 'Pregnancy Losses, Early'],
#   ['Abortion, Spontaneous', 'T000937142', 'Miscarriage'],
#   ['Abortion, Spontaneous', 'T000937142', 'Miscarriages'],
#   ['Abortion, Spontaneous', 'T000055', 'Abortion, Tubal'],
#   ['Abortion, Spontaneous', 'T000055', 'Abortions, Tubal'],
#   ['Abortion, Spontaneous', 'T000055', 'Tubal Abortion'],
#   ['Abortion, Spontaneous', 'T000055', 'Tubal Abortions']],
#  'D000026': [['Abortion, Habitual', 'T000067', 'Abortion, Habitual'],
#   ['Abortion, Habitual', 'T000067', 'Habitual Abortion'],
#   ['Abortion, Habitual', 'T000067', 'Habitual Abortions'],
#   ['Abortion, Habitual', 'T000068', 'Abortion, Recurrent'],
#   ['Abortion, Habitual', 'T000068', 'Recurrent Abortion'],
#   ['Abortion, Habitual', 'T000068', 'Recurrent Abortions'],
#   ['Abortion, Habitual', 'T000069', 'Miscarriage, Recurrent'],
#   ['Abortion, Habitual', 'T000069', 'Recurrent Miscarriage'],
#   ['Abortion, Habitual', 'T000069', 'Recurrent Miscarriages'],
#   ['Abortion, Habitual', 'T000923274', 'Recurrent Early Pregnancy Loss']],
#  'D000027': [['Abortion, Incomplete', 'T000070', 'Abortion, Incomplete'],
#   ['Abortion, Incomplete', 'T000070', 'Abortions, Incomplete'],
#   ['Abortion, Incomplete', 'T000070', 'Incomplete Abortion'],
#   ['Emotional Adjustment', 'T000874707', 'Adaptations, Emotional'],
#   ['Emotional Adjustment', 'T000874707', 'Emotional Adaptations']],
#  'D000066499': [['Facial Recognition', 'T000877950', 'Facial Recognition'],
#   ['Facial Recognition', 'T000877950', 'Recognition, Facial'],
#   ['Facial Recognition', 'T001004556', 'Face Recognition'],
#   ['Facial Recognition', 'T001004556', 'Recognition, Face'],
#   ['Facial Recognition', 'T000861979', 'Face Perception'],
#   ['Facial Recognition', 'T000861979', 'Perception, Face'],
#   ['Facial Recognition', 'T001081443', 'Facial Identity Recognition'],
#   ['Facial Recognition', 'T001081443', 'Identity Recognition, Facial'],
#   ['Facial Recognition', 'T001081443', 'Recognition, Facial Identity'],
#   ['Facial Recognition', 'T001004538', 'Face Processing'],
#   ['Facial Recognition', 'T001004538', 'Processing, Face'],
#   ['Facial Recognition', 'T001004557', 'Facial Emotion Recognition'],
#   ['Facial Recognition', 'T001004557', 'Emotion Recognition, Facial'],
#   ['Facial Recognition', 'T001004557', 'Recognition, Facial Emotion'],
#   ['Facial Recognition', 'T001004561', 'Face Emotion Perception'],
#   ['Facial Recognition', 'T001004561', 'Emotion Perception, Face'],
#   ['Facial Recognition', 'T001004561', 'Perception, Face Emotion'],
#   ['Facial Recognition', 'T001004560', 'Facial Expression Recognition'],
#   ['Facial Recognition', 'T001004560', 'Expression Recognition, Facial'],
#   ['Facial Recognition', 'T001004560', 'Recognition, Facial Expression'],
#   ['Facial Recognition', 'T001004558', 'Face Emotion Recognition'],
#   ['Facial Recognition', 'T001004558', 'Emotion Recognition, Face'],
#   ['Facial Recognition', 'T001004558', 'Recognition, Face Emotion'],
#   ['Facial Recognition', 'T001004559', 'Face Emotion Processing'],
#   ['Facial Recognition', 'T001004559', 'Emotion Processing, Face'],
#   ['Facial Recognition', 'T001004559', 'Processing, Face Emotion']],
#  'D000066502': [['Grandparents', 'T000877952', 'Grandparents'],
#   ['Grandparents', 'T000862000', 'Grandparent'],
#   ['Grandparents', 'T000874702', 'Grandmother'],
#   ['Grandparents', 'T000874702', 'Grandmothers'],
#   ['Grandparents', 'T000874703', 'Grandfather'],
#   ['Grandparents', 'T000874703', 'Grandfathers']],
#  'D000066505': [['Help-Seeking Behavior',
#    'T000862010',
#    'Help-Seeking Behavior'],
#   ['Help-Seeking Behavior', 'T000862010', 'Behavior, Help-Seeking'],
#   ['Help-Seeking Behavior', 'T000862010', 'Behaviors, Help-Seeking'],
#   ['Help-Seeking Behavior', 'T000862010', 'Help Seeking Behavior'],
#   ['Help-Seeking Behavior', 'T000862010', 'Help-Seeking Behaviors']],
#  'D000066506': [['Heuristics', 'T000862013', 'Heuristics'],
#   ['Heuristics', 'T000862013', 'Heuristic'],
#   ['Heuristics', 'T000870522', 'Rule of Thumb']],
#  'D000066553': [['Problem Behavior', 'T000862301', 'Problem Behavior'],
#   ['Problem Behavior', 'T000862301', 'Behavior, Problem'],
#   ['Problem Behavior', 'T000862301', 'Behaviors, Problem'],
#   ['Problem Behavior', 'T000862301', 'Problem Behaviors'],
#   ['Underage Drinking', 'T000868333', 'Minimum Drinking Age'],
#   ['Underage Drinking', 'T000868333', 'Drinking Age, Minimum'],
#   ['Underage Drinking', 'T000868333', 'Drinking Ages, Minimum'],
#   ['Underage Drinking', 'T000868333', 'Minimum Drinking Ages']],
#  'D000067010': [['Literacy', 'T000865866', 'Literacy'],
#   ['Literacy', 'T013849', 'Illiteracy']],
#  'D000067011': [['Severe Acute Malnutrition',
#    'T000865867',
#    'Severe Acute Malnutrition'],
#   ['Severe Acute Malnutrition', 'T000865867', 'Acute Malnutrition, Severe'],
#   ['Severe Acute Malnutrition', 'T000865867', 'Malnutrition, Severe Acute']],
#  'D000067073': [['Psychological Trauma', 'T000866236', 'Psychological Trauma'],
#   ['Psychological Trauma', 'T000866236', 'Trauma, Psychological']],
#  'D000067074': [['Peer Influence', 'T000866237', 'Peer Influence'],
#   ['Peer Influence', 'T000866237', 'Influence, Peer'],
#   ['Peer Influence', 'T000866238', 'Peer Pressure'],
#   ['Peer Influence', 'T000866238', 'Pressure, Peer']],
#  'D000067208': [['Shellfish Hypersensitivity',
#    'T000866948',
#    'Shellfish Hypersensitivity'],
#   ['Shellfish Hypersensitivity',
#    'T000866948',
#    'Hypersensitivities, Shellfish'],
#   ['Shellfish Hypersensitivity', 'T000866948', 'Hypersensitivity, Shellfish'],
#   ['Shellfish Hypersensitivity', 'T000866948', 'Shellfish Hypersensitivities'],
#   ['Shellfish Hypersensitivity', 'T000866949', 'Shellfish Allergy'],
#   ['Shellfish Hypersensitivity', 'T000866949', 'Allergies, Shellfish'],
#   ['Shellfish Hypersensitivity', 'T000866949', 'Allergy, Shellfish'],
#   ['Shellfish Hypersensitivity', 'T000866949', 'Shellfish Allergies']],
#  'D000067251': [['Symptom Flare Up', 'T000871086', 'Symptom Flare Up'],
#   ['Symptom Flare Up', 'T000871086', 'Flare Up, Symptom'],
#   ['Symptom Flare Up', 'T000871086', 'Flare Ups, Symptom'],
#   ['Symptom Flare Up', 'T000871086', 'Symptom Flare Ups'],
#   ['Symptom Flare Up', 'T000871105', 'Symptom Flaring Up'],
#   ['Symptom Flare Up', 'T000871105', 'Flaring Up, Symptom'],
#   ['Symptom Flare Up', 'T000871089', 'Acute Symptom Flare'],
#   ['Symptom Flare Up', 'T000871089', 'Acute Symptom Flares'],
#   ['Symptom Flare Up', 'T000871089', 'Symptom Flare, Acute'],
#   ['Symptom Flare Up', 'T000871087', 'Symptom Flareup'],
#   ['Symptom Flare Up', 'T000871087', 'Flareup, Symptom'],
#   ['Symptom Flare Up', 'T000871087', 'Flareups, Symptom'],
#   ['Symptom Flare Up', 'T000871087', 'Symptom Flareups'],
#   ['Symptom Flare Up', 'T000871088', 'Symptom Flare-up'],
#   ['Symptom Flare Up', 'T000871088', 'Flare-up, Symptom'],
#   ['Symptom Flare Up', 'T000871088', 'Flare-ups, Symptom'],
#   ['Symptom Flare Up', 'T000871088', 'Symptom Flare-ups'],
#   ['Symptom Flare Up', 'T000946895', 'Symptom Exacerbation'],
#   ['Symptom Flare Up', 'T000946895', 'Exacerbation, Symptom'],
#   ['Symptom Flare Up', 'T000946895', 'Symptom Exacerbations'],
#   ['Symptom Flare Up', 'T000946899', 'Symptom Increase'],
#   ['Symptom Flare Up', 'T000946899', 'Increase, Symptom'],
#   ['Symptom Flare Up', 'T000946897', 'Symptom Magnification'],
#   ['Symptom Flare Up', 'T000946897', 'Magnification, Symptom'],
#   ['Symptom Flare Up', 'T000946897', 'Symptom Magnifications'],
#   ['Symptom Flare Up', 'T000946898', 'Symptom Worsening'],
#   ['Symptom Flare Up', 'T000946898', 'Worsening, Symptom'],
#   ['Symptom Flare Up', 'T000946896', 'Symptom Exaggeration'],
#   ['Symptom Flare Up', 'T000946896', 'Exaggeration, Symptom'],
#   ['Symptom Flare Up', 'T000946896', 'Symptom Exaggerations']],
#  'D000067289': [['Behavior Observation Techniques',
#    'T000869172',
#    'Behavior Observation Techniques'],
#   ['Behavior Observation Techniques',
#    'T000869172',
#    'Behavior Observation Technique'],
#   ['Behavior Observation Techniques',
#    'T000869172',
#    'Observation Technique, Behavior'],
#   ['Behavior Observation Techniques',
#    'T000869172',
#    'Observation Techniques, Behavior'],
#   ['Behavior Observation Techniques',
#    'T000869173',
#    'Behavioral Observation Techniques'],
#   ['Behavior Observation Techniques',
#    'T000869173',
#    'Behavioral Observation Technique'],
#   ['Behavior Observation Techniques',
#    'T000869173',
#    'Observation Technique, Behavioral'],
#   ['Behavior Observation Techniques',
#    'T000869173',
#    'Observation Techniques, Behavioral'],
#   ['Behavior Observation Techniques', 'T000867286', 'Behavior Observation'],
#   ['Behavior Observation Techniques', 'T000867286', 'Behavior Observations'],
#   ['Behavior Observation Techniques', 'T000867286', 'Observation, Behavior'],
#   ['Behavior Observation Techniques', 'T000867286', 'Observations, Behavior'],
#   ['Behavior Observation Techniques', 'T000867287', 'Behavioral Observation'],
#   ['Behavior Observation Techniques', 'T000867287', 'Behavioral Observations'],
#   ['Behavior Observation Techniques', 'T000867287', 'Observation, Behavioral'],
#   ['Behavior Observation Techniques',
#    'T000867287',
#    'Observations, Behavioral']],
#  'D000067290': [['Behavior Rating Scale',
#    'T000867288',
#    'Behavior Rating Scale'],
#   ['Behavior Rating Scale', 'T000867288', 'Behavior Rating Scales'],
#   ['Behavior Rating Scale', 'T000867288', 'Rating Scale, Behavior'],
#   ['Behavior Rating Scale', 'T000867288', 'Rating Scales, Behavior'],
#   ['Behavior Rating Scale', 'T000867289', 'Behavioral Rating Scale'],
#   ['Behavior Rating Scale', 'T000867289', 'Behavioral Rating Scales'],
#   ['Behavior Rating Scale', 'T000867289', 'Rating Scale, Behavioral'],
#   ['Behavior Rating Scale', 'T000867289', 'Rating Scales, Behavioral'],
#   ['Behavior Rating Scale', 'T000867289', 'Scale, Behavioral Rating'],
#   ['Behavior Rating Scale', 'T000867291', 'Behavior Test'],
#   ['Behavior Rating Scale', 'T000867291', 'Behavior Tests'],
#   ['Behavior Rating Scale', 'T000867291', 'Test, Behavior'],
#   ['Behavior Rating Scale', 'T000867291', 'Tests, Behavior'],
#   ['Behavior Rating Scale', 'T000867292', 'Behavioral Test'],
#   ['Behavior Rating Scale', 'T000867292', 'Behavioral Tests'],
#   ['Behavior Rating Scale', 'T000867292', 'Test, Behavioral'],
#   ['Behavior Rating Scale', 'T000867292', 'Tests, Behavioral']],
#  'D000067292': [['Alcohol Drinking in College',
#    'T000871165',
#    'Alcohol Drinking in College'],
#   ['Alcohol Drinking in College', 'T000870990', 'College Student Drinking'],
#   ['Alcohol Drinking in College', 'T000870990', 'Student Drinking, College'],
#   ['Alcohol Drinking in College',
#    'T000870992',
#    'Alcohol Drinking, College Students'],
#   ['Alcohol Drinking in College', 'T000867306', 'College Drinking'],
#   ['Alcohol Drinking in College', 'T000867306', 'Drinking, College'],
#   ['Alcohol Drinking in College', 'T000870991', 'University Student Drinking'],
#   ['Alcohol Drinking in College',
#    'T000870991',
#    'Student Drinking, University']],
#  'D000067329': [['Obesity, Metabolically Benign',
#    'T000867594',
#    'Obesity, Metabolically Benign'],
#   ['Obesity, Metabolically Benign',
#    'T000867594',
#    'Benign Obesity, Metabolically'],
#   ['Obesity, Metabolically Benign',
#    'T000867592',
#    'Metabolically Benign Obesity'],
#   ['Obesity, Metabolically Benign',
#    'T000867593',
#    'Metabolically Healthy Obesity'],
#   ['Obesity, Metabolically Benign',
#    'T000867593',
#    'Healthy Obesity, Metabolically'],
#   ['Obesity, Metabolically Benign',
#    'T000867593',
#    'Obesity, Metabolically Healthy']],
#  'D000067390': [['Cold Injury', 'T000869087', 'Cold Injury'],
#   ['Cold Injury', 'T000869087', 'Cold Injuries'],
#   ['Cold Injury', 'T000869087', 'Injuries, Cold'],
#   ['Cold Injury', 'T000869087', 'Injury, Cold']],
#  'D000067398': [['War-Related Injuries', 'T000869128', 'War-Related Injuries'],
#   ['War-Related Injuries', 'T000869128', 'Injuries, War-Related'],
#   ['War-Related Injuries', 'T000869128', 'Injury, War-Related'],
#   ['War-Related Injuries', 'T000869128', 'War Related Injuries'],
#   ['War-Related Injuries', 'T000869128', 'War-Related Injury'],
#   ['War-Related Injuries', 'T000870514', 'War-Related Trauma'],
#   ['War-Related Injuries', 'T000870514', 'Trauma, War-Related'],
#   ['War-Related Injuries', 'T000870514', 'War Related Trauma']],
#  'D000067404': [['Social Communication Disorder',
#    'T000869260',
#    'Social Communication Disorder'],
#   ['Social Communication Disorder',
#    'T000869260',
#    'Communication Disorder, Social'],
#   ['Social Communication Disorder',
#    'T000869260',
#    'Communication Disorders, Social'],
#   ['Social Communication Disorder',
#    'T000869260',
#    'Social Communication Disorders'],
#   ['Social Communication Disorder',
#    'T000869261',
#    'Pragmatic Communication Disorder'],
#   ['Social Communication Disorder',
#    'T000869261',
#    'Communication Disorder, Pragmatic'],
#   ['Social Communication Disorder',
#    'T000869261',
#    'Communication Disorders, Pragmatic'],
#   ['Social Communication Disorder',
#    'T000869261',
#    'Disorders, Pragmatic Communication'],
#   ['Social Communication Disorder',
#   ['Late Onset Disorders', 'T000871571', 'Disease, Late Onset'],
#   ['Late Onset Disorders', 'T000871571', 'Diseases, Late Onset'],
#   ['Late Onset Disorders', 'T000871571', 'Late Onset Disease'],
#   ['Late Onset Disorders', 'T000871571', 'Onset Disease, Late'],
#   ['Late Onset Disorders', 'T000871571', 'Onset Diseases, Late']],
#  'D000067570': [['Social Learning', 'T000871620', 'Social Learning'],
#   ['Social Learning', 'T000871620', 'Learning, Social']],
#  'D000067656': [['Optimism', 'T000872101', 'Optimism'],
#   ['Optimism', 'T001080651', 'Positive Attitude'],
#   ['Optimism', 'T001080651', 'Attitude, Positive'],
#   ['Optimism', 'T000894300', 'Positive Thinking']],
#  'D000067657': [['Pessimism', 'T000872102', 'Pessimism'],
#   ['Pessimism', 'T000896269', 'Negative Thinking'],
#   ['Pessimism', 'T000896269', 'Thinking, Negative']],
#  'D000067836': [['Hoarding Disorder', 'T000873004', 'Hoarding Disorder'],
#   ['Hoarding Disorder', 'T000873004', 'Disorders, Hoarding'],
#   ['Hoarding Disorder', 'T000873004', 'Hoarding Disorders'],
#   ['Hoarding Disorder', 'T788417', 'Obsessive Hoarding'],
#   ['Hoarding Disorder', 'T788417', 'Hoarding, Obsessive']],
#  'D000067877': [['Autism Spectrum Disorder',
#    'T000876248',
#    'Autism Spectrum Disorder'],
#   ['Autism Spectrum Disorder', 'T750206', 'Autism Spectrum Disorders'],
#   ['Autism Spectrum Disorder', 'T001080655', 'Autistic Spectrum Disorder'],
#   ['Autism Spectrum Disorder', 'T001080655', 'Autistic Spectrum Disorders'],
#   ['Autism Spectrum Disorder', 'T001080655', 'Disorder, Autistic Spectrum']],
#  'D000068079': [['Motor Disorders', 'T000873855', 'Motor Disorders']],
#  'D000068099': [['Trauma and Stressor Related Disorders',
#    'T000873985',
#    'Trauma and Stressor Related Disorders'],
#   ['Trauma and Stressor Related Disorders',
#    'T001106471',
#    'Trauma and Stress Related Disorders']],
#  'D000068105': [['Bipolar and Related Disorders',
#    'T000874002',
#    'Bipolar and Related Disorders']],
#  'D000068116': [['Gender Dysphoria', 'T000874099', 'Gender Dysphoria'],
#   ['Gender Dysphoria', 'T001080619', 'Gender Identity Disorder'],
#   ['Gender Dysphoria', 'T001080619', 'Disorder, Gender Identity'],
#   ['Gender Dysphoria', 'T001080619', 'Gender Identity Disorders'],
#   ['Gender Dysphoria', 'T001080619', 'Identity Disorder, Gender']],
#  'D000068156': [['Formative Feedback', 'T000874480', 'Formative Feedback'],
#   ['Formative Feedback', 'T000874480', 'Feedback, Formative'],
#   ['Formative Feedback', 'T000874479', 'Constructive Feedback'],
#   ['Formative Feedback', 'T000874479', 'Feedback, Constructive'],
#   ['Formative Feedback', 'T000874478', 'Feedback (Learning)']],
#  'D000068237': [['Distance Counseling', 'T000874788', 'Distance Counseling'],
#   ['Distance Counseling', 'T000874788', 'Counseling, Distance'],
#   ['Distance Counseling', 'T000882079', 'E-Therapy'],
#   ['Distance Counseling', 'T000882079', 'E Therapy'],
#   ['Distance Counseling', 'T000882079', 'E-Therapies'],
#   ['Autoimmune Hypophysitis', 'T000880329', 'Panhypophysitis, Lymphocytic'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Anti-PIT-1 Antibody Syndrome'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Anti PIT 1 Antibody Syndrome'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Anti-PIT-1 Antibody Syndromes'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Antibody Syndrome, Anti-PIT-1'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Antibody Syndromes, Anti-PIT-1'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Syndrome, Anti-PIT-1 Antibody'],
#   ['Autoimmune Hypophysitis', 'T000880314', 'Syndromes, Anti-PIT-1 Antibody'],
#   ['Autoimmune Hypophysitis',
#    'T000879309',
#    'Idiopathic Granulomatous Hypophysitis'],
#   ['Autoimmune Hypophysitis',
#    'T000879309',
#    'Granulomatous Hypophysitides, Idiopathic'],
#   ['Autoimmune Hypophysitis',
#    'T000879309',
#    'Granulomatous Hypophysitis, Idiopathic'],
#   ['Autoimmune Hypophysitis',
#    'T000879309',
#    'Hypophysitides, Idiopathic Granulomatous'],
#   ['Autoimmune Hypophysitis',
#    'T000879309',
#    'Hypophysitis, Idiopathic Granulomatous'],
#   ['Autoimmune Hypophysitis',
#    'T000879309',
#    'Idiopathic Granulomatous Hypophysitides'],
#   ['Autoimmune Hypophysitis', 'T000879305', 'IgG4-Related Hypophysitis'],
#   ['Autoimmune Hypophysitis', 'T000879305', 'Hypophysitides, IgG4-Related'],
#   ['Autoimmune Hypophysitis', 'T000879305', 'Hypophysitis, IgG4-Related'],
#   ['Autoimmune Hypophysitis', 'T000879305', 'IgG4 Related Hypophysitis'],
#   ['Autoimmune Hypophysitis', 'T000879305', 'IgG4-Related Hypophysitides'],
#   ['Autoimmune Hypophysitis',
#    'T000880328',
#    'Lymphocytic Infundibuloneurohypophysitis'],
#   ['Autoimmune Hypophysitis',
#    'T000880328',
#    'Infundibuloneurohypophysitides, Lymphocytic'],
#   ['Autoimmune Hypophysitis',
#    'T000880328',
#    'Infundibuloneurohypophysitis, Lymphocytic'],
#   ['Autoimmune Hypophysitis',
#    'T000880328',
#    'Lymphocytic Infundibuloneurohypophysitides'],
#   ['Autoimmune Hypophysitis', 'T000879304', 'Lymphocytic Adenohypophysitis'],
#   ['Autoimmune Hypophysitis',
#    'T000879304',
#    'Adenohypophysitides, Lymphocytic'],
#   ['Autoimmune Hypophysitis', 'T000879304', 'Adenohypophysitis, Lymphocytic'],
#   ['Autoimmune Hypophysitis',
#    'T000879304',
#    'Lymphocytic Adenohypophysitides']],
#  'D000069282': [['Canaliculitis', 'T745715', 'Canaliculitis'],
#   ['Canaliculitis', 'T745715', 'Canaliculitides'],
#   ['Canaliculitis', 'T000879317', 'Lacrimal Canaliculitis'],
#   ['Canaliculitis', 'T000879317', 'Canaliculitides, Lacrimal'],
#   ['Canaliculitis', 'T000879317', 'Canaliculitis, Lacrimal'],
#   ['Canaliculitis', 'T000879317', 'Lacrimal Canaliculitides']],
#  'D000069290': [['Incisional Hernia', 'T000879378', 'Incisional Hernia'],
#   ['Incisional Hernia', 'T000879378', 'Hernia, Incisional'],
#   ['Incisional Hernia', 'T000879378', 'Hernias, Incisional'],
#   ['Incisional Hernia', 'T000879378', 'Incisional Hernias'],
#   ['Incisional Hernia', 'T000879379', 'Postoperative Hernia'],
#   ['Incisional Hernia', 'T000879379', 'Hernia, Postoperative'],
#   ['Incisional Hernia', 'T000879379', 'Hernias, Postoperative'],
#   ['Incisional Hernia', 'T000879379', 'Postoperative Hernias']],
#  'D000069293': [['Plasmablastic Lymphoma',
#    'T000879390',
#    'Plasmablastic Lymphoma'],
#   ['Plasmablastic Lymphoma', 'T000879390', 'Lymphoma, Plasmablastic'],
#   ['Plasmablastic Lymphoma', 'T000879390', 'Lymphomas, Plasmablastic'],
#   ['Plasmablastic Lymphoma', 'T000879390', 'Plasmablastic Lymphomas'],
#   ['Plasmablastic Lymphoma',
#    'T000879392',
#    'Plasmablasts Diffuse Large B-cell Lymphoma'],
#   ['Plasmablastic Lymphoma',
#    'T000879392',
#    'Plasmablasts Diffuse Large B cell Lymphoma'],
#   ['Plasmablastic Lymphoma',
#    'T000879391',
#    'Plasmablastic Diffuse Large B-cell Lymphoma'],
#   ['Plasmablastic Lymphoma',
#    'T000879391',
#    'Plasmablastic Diffuse Large B cell Lymphoma']],
#  'D000069295': [['Mammary Analogue Secretory Carcinoma',
#    'T000879394',
#    'Mammary Analogue Secretory Carcinoma']],
#  'D000069316': [['Acne Conglobata', 'T000879435', 'Acne Conglobata'],
#   ['Acne Conglobata', 'T000879435', 'Acne Conglobatas'],
#   ['Acne Conglobata', 'T000879435', 'Conglobata, Acne'],
#   ['Acne Conglobata', 'T000879435', 'Conglobatas, Acne']],
#  'D000069337': [['Fused Kidney', 'T000879548', 'Fused Kidney'],
#   ['Fused Kidney', 'T000879548', 'Fused Kidneys'],
#   ['Fused Kidney', 'T000879548', 'Kidney, Fused'],
#   ['Fused Kidney', 'T000879548', 'Kidneys, Fused'],
#   ['Fused Kidney', 'T000879549', 'Fusion of Kidney'],
#   ['Fused Kidney', 'T000879549', 'Kidney Fusion'],
#   ['Fused Kidney', 'T000879549', 'Kidney Fusions'],
#   ['Fused Kidney', 'T000879553', 'Renal Fusion'],
#   ['Fused Kidney', 'T000879553', 'Fusion, Renal'],
#   ['Fused Kidney', 'T000879553', 'Fusions, Renal'],
#   ['Fused Kidney', 'T000879553', 'Renal Fusions'],
#   ['Fused Kidney', 'T000879551', 'Congenital Fusion of Kidneys'],
#   ['Fused Kidney', 'T000879552', 'Congenital Lobulation of Kidneys'],
#   ['Fused Kidney', 'T000879547', 'Lobulated Kidney'],
#   ['Fused Kidney', 'T000879547', 'Kidney, Lobulated'],
#   ['Fused Kidney', 'T000879547', 'Kidneys, Lobulated'],
#   ['Fused Kidney', 'T000879547', 'Lobulated Kidneys'],
#   ['Fused Kidney', 'T000879550', 'Lobulation of Kidney'],
#   ['Fused Kidney', 'T000879550', 'Kidney Lobulation'],
#   ['Fused Kidney', 'T000879550', 'Kidney Lobulations'],
#   ['Fused Kidney', 'T000880436', 'Crossed Fused Ectopia'],
#   ['Fused Kidney', 'T000880436', 'Crossed Fused Ectopias'],
#   ['Fused Kidney', 'T000880437', 'Crossed Fused Ectopia of Kidneys'],
#   ['Fused Kidney', 'T000880433', 'Cake Kidney'],
#   ['Fused Kidney', 'T000880433', 'Cake Kidneys'],
#   ['Fused Kidney', 'T000880433', 'Kidney, Cake'],
#   ['Fused Kidney', 'T000880433', 'Kidneys, Cake'],
#   ['Fused Kidney', 'T000880438', 'Pelvic Cake Kidney'],
#   ['Fused Kidney', 'T000880438', 'Pelvic Cake Kidneys'],
#   ['Fused Kidney', 'T000879546', 'Horseshoe Kidney'],
#   ['Fused Kidney', 'T000879546', 'Horseshoe Kidneys'],
#   ['Fused Kidney', 'T000879546', 'Kidney, Horseshoe'],
#   ['Fused Kidney', 'T000879546', 'Kidneys, Horseshoe']],
#  'D000069451': [['Long Term Adverse Effects',
#    'T000880050',
#    'Long Term Adverse Effects'],
#   ['Long Term Adverse Effects', 'T000881685', 'Adverse Effects, Long Term']],
#  'D000069544': [['Infectious Encephalitis',
#    'T367445',
#    'Infectious Encephalitis'],
#   ['Infectious Encephalitis', 'T367446', 'Encephalitis, Infectious'],
#   ['Infectious Encephalitis', 'T000880605', 'Encephalitis Infection'],
#   ['Infectious Encephalitis', 'T000880605', 'Encephalitis Infections'],
#   ['Infectious Encephalitis', 'T000880605', 'Infection, Encephalitis'],
#   ['Infectious Encephalitis', 'T000880605', 'Infections, Encephalitis']],
#  'D000069551': [['Environmental Psychology',
#    'T000880606',
#    'Environmental Psychology'],
#   ['Environmental Psychology', 'T000880606', 'Psychology, Environmental']],
#  'D000069578': [['Waterborne Diseases', 'T000880685', 'Waterborne Diseases'],
#   ['Waterborne Diseases', 'T000880685', 'Disease, Waterborne'],
#   ['Waterborne Diseases', 'T000880685', 'Diseases, Waterborne'],
#   ['Waterborne Diseases', 'T000880685', 'Waterborne Disease'],
#   ['Waterborne Diseases', 'T000880683', 'Water-related Diseases'],
#   ['Waterborne Diseases', 'T000880683', 'Disease, Water-related'],
#   ['Waterborne Diseases', 'T000880683', 'Diseases, Water-related'],
#   ['Waterborne Diseases', 'T000880683', 'Water related Diseases'],
#   ['Waterborne Diseases', 'T000880683', 'Water-related Disease']],
#  'D000069584': [['Unilateral Breast Neoplasms',
#    'T000881620',
#    'Unilateral Breast Neoplasms'],
# ...
#   ['Bronchiolitis Obliterans', 'T005664', 'Bronchiolitis, Exudative'],
#   ['Bronchiolitis Obliterans', 'T005664', 'Bronchiolitides, Exudative'],
#   ['Bronchiolitis Obliterans', 'T005664', 'Exudative Bronchiolitides'],
#   ['Bronchiolitis Obliterans', 'T703161', 'Exudative Bronchiolitis'],
#   ['Bronchiolitis Obliterans', 'T005666', 'Bronchiolitis, Proliferative'],
#   ['Bronchiolitis Obliterans', 'T005665', 'Proliferative Bronchiolitis'],
#   ['Bronchiolitis Obliterans', 'T005665', 'Bronchiolitides, Proliferative'],
#   ['Bronchiolitis Obliterans', 'T005665', 'Proliferative Bronchiolitides']],
#  'D001990': [['Bronchiolitis, Viral', 'T005667', 'Bronchiolitis, Viral'],
#   ['Bronchiolitis, Viral', 'T005667', 'Bronchiolitides, Viral'],
#   ['Bronchiolitis, Viral', 'T005667', 'Viral Bronchiolitides'],
#   ['Bronchiolitis, Viral', 'T005667', 'Viral Bronchiolitis']],
#  'D001991': [['Bronchitis', 'T005668', 'Bronchitis'],
#   ['Bronchitis', 'T005668', 'Bronchitides']],
#  'D001994': [['Bronchogenic Cyst', 'T005680', 'Bronchogenic Cyst'],
#   ['Bronchogenic Cyst', 'T005680', 'Bronchogenic Cysts'],
#   ['Bronchogenic Cyst', 'T005680', 'Cyst, Bronchogenic'],
#   ['Bronchogenic Cyst', 'T005680', 'Cysts, Bronchogenic'],
#   ['Bronchogenic Cyst', 'T005679', 'Bronchial Cyst'],
#   ['Bronchogenic Cyst', 'T005679', 'Bronchial Cysts'],
#   ['Bronchogenic Cyst', 'T005679', 'Cyst, Bronchial'],
#   ['Bronchogenic Cyst', 'T005679', 'Cysts, Bronchial']],
#  'D001996': [['Bronchopneumonia', 'T005682', 'Bronchopneumonia'],
#   ['Bronchopneumonia', 'T005682', 'Bronchopneumonias'],
#   ['Bronchopneumonia', 'T717750', 'Bronchial Pneumonia'],
#   ['Bronchopneumonia', 'T717750', 'Bronchial Pneumonias'],
#   ['Bronchopneumonia', 'T717750', 'Pneumonia, Bronchial'],
#   ['Bronchopneumonia', 'T717750', 'Pneumonias, Bronchial']],
#  'D001997': [['Bronchopulmonary Dysplasia',
#    'T005683',
#    'Bronchopulmonary Dysplasia'],
#   ['Bronchopulmonary Dysplasia', 'T005683', 'Dysplasia, Bronchopulmonary']],
#  'D001998': [['Bronchopulmonary Sequestration',
#    'T005685',
#    'Bronchopulmonary Sequestration'],
#   ['Bronchopulmonary Sequestration', 'T005687', 'Pulmonary Sequestration'],
#   ['Bronchopulmonary Sequestration', 'T005691', 'Sequestrations, Pulmonary'],
#   ['Bronchopulmonary Sequestration',
#    'T005684',
#    'Sequestration, Bronchopulmonary'],
#   ['Bronchopulmonary Sequestration', 'T005686', 'Sequestration, Pulmonary'],
#   ['Bronchopulmonary Sequestration',
#    'T005689',
#    'Sequestrations, Bronchopulmonary'],
#   ['Bronchopulmonary Sequestration',
#    'T005688',
#    'Bronchopulmonary Sequestrations'],
#   ['Bronchopulmonary Sequestration', 'T005690', 'Pulmonary Sequestrations']],
#  'D002006': [['Brucellosis', 'T005701', 'Brucellosis'],
#   ['Brucellosis', 'T005701', 'Brucelloses'],
#   ['Brucellosis', 'T005702', 'Malta Fever'],
#   ['Brucellosis', 'T005702', 'Fever, Malta'],
#   ['Brucellosis', 'T781818', 'Gibraltar Fever'],
#   ['Brucellosis', 'T781818', 'Fever, Gibraltar'],
#   ['Brucellosis', 'T781816', 'Rock Fever'],
#   ['Brucellosis', 'T781816', 'Fever, Rock'],
#   ['Brucellosis', 'T781817', 'Cyprus Fever'],
#   ['Brucellosis', 'T781817', 'Fever, Cyprus'],
#   ['Brucellosis', 'T000908590', 'Brucella Infection'],
#   ['Brucellosis', 'T000908590', 'Brucella Infections'],
#   ['Brucellosis', 'T000908590', 'Infection, Brucella'],
#   ['Brucellosis', 'T005703', 'Undulant Fever'],
#   ['Brucellosis', 'T005703', 'Fever, Undulant'],
#   ['Brucellosis', 'T785314', 'Brucellosis, Pulmonary'],
#   ['Brucellosis', 'T785314', 'Brucelloses, Pulmonary'],
#   ['Brucellosis', 'T785314', 'Pulmonary Brucelloses'],
#   ['Brucellosis', 'T785314', 'Pulmonary Brucellosis']],
#  'D002007': [['Brucellosis, Bovine', 'T005706', 'Brucellosis, Bovine'],
#   ['Brucellosis, Bovine', 'T005706', 'Bovine Brucelloses'],
#   ['Brucellosis, Bovine', 'T005706', 'Bovine Brucellosis'],
#   ['Brucellosis, Bovine', 'T005706', 'Brucelloses, Bovine'],
#   ['Brucellosis, Bovine', 'T005705', "Bang's Disease"],
#   ['Brucellosis, Bovine', 'T005705', 'Bangs Disease'],
#   ['Brucellosis, Bovine', 'T005705', "Disease, Bang's"],
#   ['Brucellosis, Bovine', 'T005704', 'Bang Disease'],
#   ['Brucellosis, Bovine', 'T005704', 'Disease, Bang']],
#  'D002012': [['Bruxism', 'T005710', 'Bruxism'],
#   ['Bruxism', 'T401321', 'Teeth Grinding Disorder'],
#   ['Bruxism', 'T401321', 'Disorder, Teeth Grinding'],
#   ['Bruxism', 'T401321', 'Grinding Disorder, Teeth'],
#   ['Bruxism', 'T401321', 'Teeth Grinding Disorders'],
#   ['Bruxism', 'T001080640', 'Bruxomania']],
#  'D002032': [['Bulimia', 'T005763', 'Bulimia'],
#   ['Bulimia', 'T005763', 'Bulimias'],
#   ['Bulimia', 'T402123', 'Binge Eating'],
#   ['Bulimia', 'T402123', 'Eating, Binge']],
#  'D002037': [['Bundle-Branch Block', 'T005775', 'Bundle-Branch Block'],
#   ['Bundle-Branch Block', 'T005775', 'Block, Bundle-Branch'],
#   ['Bundle-Branch Block', 'T005775', 'Blocks, Bundle-Branch'],
#   ['Bundle-Branch Block', 'T005775', 'Bundle-Branch Blocks'],
#   ['Bundle-Branch Block', 'T816813', 'Bundle Branch Block'],
#   ['Bundle-Branch Block', 'T816813', 'Block, Bundle Branch'],
#   ['Bundle-Branch Block', 'T816813', 'Blocks, Bundle Branch'],
#   ['Bundle-Branch Block', 'T816813', 'Branch Block, Bundle'],
#   ['Bundle-Branch Block', 'T816813', 'Branch Blocks, Bundle'],
#   ['Bundle-Branch Block', 'T816813', 'Bundle Branch Blocks'],
#   ['Bundle-Branch Block', 'T681765', 'Right Bundle-Branch Block'],
#   ['Bundle-Branch Block', 'T681765', 'Block, Right Bundle-Branch'],
#   ['Bundle-Branch Block', 'T681765', 'Blocks, Right Bundle-Branch'],
#   ['Bundle-Branch Block', 'T681765', 'Bundle-Branch Block, Right'],
#   ['Bundle-Branch Block', 'T681765', 'Bundle-Branch Blocks, Right'],
#   ['Bundle-Branch Block', 'T681765', 'Right Bundle Branch Block'],
#   ['Bundle-Branch Block', 'T681765', 'Right Bundle-Branch Blocks'],
#   ['Bundle-Branch Block', 'T681764', 'Left Bundle-Branch Block'],
#   ['Bundle-Branch Block', 'T681764', 'Block, Left Bundle-Branch'],
#   ['Bundle-Branch Block', 'T681764', 'Blocks, Left Bundle-Branch'],
#   ['Bundle-Branch Block', 'T681764', 'Bundle-Branch Block, Left'],
#   ['Bundle-Branch Block', 'T681764', 'Bundle-Branch Blocks, Left'],
#   ['Bundle-Branch Block', 'T681764', 'Left Bundle Branch Block'],
#   ['Bundle-Branch Block', 'T681764', 'Left Bundle-Branch Blocks'],
#   ['Bundle-Branch Block', 'T681767', 'Posterior Fascicular Block'],
#   ['Bundle-Branch Block', 'T681767', 'Block, Posterior Fascicular'],
#   ['Bundle-Branch Block', 'T681767', 'Blocks, Posterior Fascicular'],
#   ['Bundle-Branch Block', 'T681767', 'Fascicular Block, Posterior'],
#   ['Bundle-Branch Block', 'T681767', 'Fascicular Blocks, Posterior'],
#   ['Bundle-Branch Block', 'T681767', 'Posterior Fascicular Blocks'],
#   ['Bundle-Branch Block', 'T681766', 'Anterior Fascicular Block'],
#   ['Bundle-Branch Block', 'T681766', 'Anterior Fascicular Blocks'],
#   ['Bundle-Branch Block', 'T681766', 'Block, Anterior Fascicular'],
#   ['Bundle-Branch Block', 'T681766', 'Blocks, Anterior Fascicular'],
#   ['Bundle-Branch Block', 'T681766', 'Fascicular Block, Anterior'],
#   ['Bundle-Branch Block', 'T681766', 'Fascicular Blocks, Anterior'],
#   ['Bundle-Branch Block', 'T005776', 'Fascicular Block'],
#   ['Bundle-Branch Block', 'T005776', 'Block, Fascicular'],
#   ['Bundle-Branch Block', 'T005776', 'Blocks, Fascicular'],
#   ['Bundle-Branch Block', 'T005776', 'Fascicular Blocks']],
#  'D002044': [['Bunyaviridae Infections', 'T005794', 'Bunyaviridae Infections'],
#   ['Bunyaviridae Infections', 'T005794', 'Bunyaviridae Infection'],
#   ['Bunyaviridae Infections', 'T005793', 'Infections, Bunyaviridae'],
#   ['Bunyaviridae Infections',
#    'T000946443',
#    'Oropouche Orthobunyavirus Infection'],
#   ['Bunyaviridae Infections',
#    'T000946443',
#    'Orthobunyavirus Infection, Oropouche'],
#   ['Bunyaviridae Infections', 'T000946445', 'Oropouche Infection'],
#   ['Bunyaviridae Infections', 'T000946446', 'Oropouche Fever'],
#   ['Bunyaviridae Infections', 'T000946446', 'Oropouche Fevers'],
#   ['Bunyaviridae Infections', 'T000946444', 'Oropouche Virus Infection'],
#   ['Bunyaviridae Infections', 'T000946444', 'Virus Infection, Oropouche'],
#   ['Bunyaviridae Infections', 'T005795', 'Infections, Bunyavirus'],
#   ['Bunyaviridae Infections', 'T005795', 'Bunyavirus Infection'],
#  'D002056': [['Burns', 'T005831', 'Burns'], ['Burns', 'T005831', 'Burn']],
#  'D002057': [['Burns, Chemical', 'T005833', 'Burns, Chemical'],
#   ['Burns, Chemical', 'T005832', 'Chemical Burns'],
#   ['Burns, Chemical', 'T005832', 'Burn, Chemical'],
#   ['Burns, Chemical', 'T005832', 'Chemical Burn']],
#  'D002058': [['Burns, Electric', 'T005835', 'Burns, Electric'],
#   ['Burns, Electric', 'T005834', 'Electric Burns'],
#   ['Burns, Electric', 'T005834', 'Burn, Electric'],
#   ['Burns, Electric', 'T005834', 'Electric Burn']],
#  'D002059': [['Burns, Inhalation', 'T005837', 'Burns, Inhalation'],
#   ['Burns, Inhalation', 'T005836', 'Inhalation Burns'],
#   ['Burns, Inhalation', 'T005836', 'Burn, Inhalation'],
#   ['Burns, Inhalation', 'T005836', 'Inhalation Burn']],
#  'D002062': [['Bursitis', 'T005840', 'Bursitis'],
#   ['Bursitis', 'T005840', 'Bursitides'],
#   ['Bursitis', 'T731218', 'Frozen Shoulder'],
#   ['Bursitis', 'T731218', 'Frozen Shoulders'],
#   ['Bursitis', 'T731218', 'Shoulder, Frozen'],
#   ['Bursitis', 'T000890516', 'Adhesive Capsulitis of the Shoulder'],
#   ['Bursitis', 'T000890517', 'Shoulder Adhesive Capsulitis'],
#   ['Bursitis', 'T000890517', 'Adhesive Capsulitides, Shoulder'],
#   ['Bursitis', 'T000890517', 'Adhesive Capsulitis, Shoulder'],
#   ['Bursitis', 'T000890517', 'Capsulitides, Shoulder Adhesive'],
#   ['Bursitis', 'T000890517', 'Capsulitis, Shoulder Adhesive'],
#   ['Bursitis', 'T000890517', 'Shoulder Adhesive Capsulitides'],
#   ['Bursitis', 'T000890512', 'Capsulitis'],
#   ['Bursitis', 'T000890512', 'Capsulitides'],
#   ['Bursitis', 'T000950622', 'Pes Anserine Bursitis'],
#   ['Bursitis', 'T000950622', 'Bursitides, Pes Anserine'],
#   ['Bursitis', 'T000950622', 'Bursitis, Pes Anserine'],
#   ['Bursitis', 'T000950622', 'Pes Anserine Bursitides'],
#   ['Bursitis', 'T005841', 'Adhesive Capsulitis'],
#   ['Bursitis', 'T005841', 'Adhesive Capsulitides'],
#   ['Bursitis', 'T005841', 'Capsulitides, Adhesive'],
#   ['Bursitis', 'T005842', 'Capsulitis, Adhesive']],
#  'D002095': [['Byssinosis', 'T005952', 'Byssinosis'],
#   ['Byssinosis', 'T005952', 'Byssinoses'],
#   ['Byssinosis', 'T708912', 'Brown Lung'],
#   ['Byssinosis', 'T708912', 'Brown Lungs'],
#   ['Byssinosis', 'T708911', 'Brown Lung Disease'],
#   ['Byssinosis', 'T708911', 'Brown Lung Diseases']],
#  'D002100': [['Cachexia', 'T005960', 'Cachexia']],
#  'D002102': [['Cadaver', 'T005966', 'Cadaver'],
#   ['Cadaver', 'T005966', 'Cadavers'],
#   ['Cadaver', 'T734072', 'Corpse'],
#   ['Cadaver', 'T734072', 'Corpses']],
#  'D002105': [['Cadmium Poisoning', 'T005973', 'Cadmium Poisoning'],
#   ['Cadmium Poisoning', 'T005972', 'Poisoning, Cadmium'],
#   ['Cadmium Poisoning', 'T005972', 'Cadmium Poisonings'],
#   ['Cadmium Poisoning', 'T005972', 'Poisonings, Cadmium'],
#   ['Cadmium Poisoning', 'T005974', 'Itai-Itai'],
#   ['Cadmium Poisoning', 'T005974', 'Itai Itai']],
#  'D002114': [['Calcinosis', 'T005999', 'Calcinosis'],
#   ['Calcinosis', 'T005999', 'Calcinoses'],
#   ['Calcinosis', 'T006001', 'Calcification, Pathologic'],
#   ['Calcinosis', 'T006000', 'Pathologic Calcification'],
#   ['Calcinosis', 'T000897627', 'Microcalcification'],
#   ['Calcinosis', 'T000897627', 'Microcalcifications'],
#   ['Calcinosis', 'T000897628', 'Microcalcinosis'],
#   ['Calcinosis', 'T000897628', 'Microcalcinoses'],
#   ['Calcinosis', 'T840711', 'Calcinosis, Tumoral'],
#   ['Calcinosis', 'T840711', 'Calcinoses, Tumoral'],
#   ['Calcinosis', 'T840711', 'Tumoral Calcinoses'],
#   ['Calcinosis', 'T840711', 'Tumoral Calcinosis']],
#  'D002115': [['Calciphylaxis', 'T006002', 'Calciphylaxis'],
#   ['Calciphylaxis', 'T764028', 'Idiopathic Calciphylaxis'],
#   ['Calciphylaxis', 'T764028', 'Calciphylaxis, Idiopathic'],
#   ['Calciphylaxis', 'T006003', 'Calciphylaxes'],
#   ['Calciphylaxis', 'T001110769', 'Calcific Uraemic Arteriolopathy'],
#   ['Calciphylaxis', 'T001110769', 'Arteriolopathy, Calcific Uraemic'],
#   ['Calciphylaxis', 'T001110769', 'Calcific Uraemic Arteriolopathies'],
#   ['Calciphylaxis', 'T001110769', 'Uraemic Arteriolopathy, Calcific']],
#  'D002128': [['Calcium Metabolism Disorders',
#    'T006066',
#    'Calcium Metabolism Disorders'],
#   ['Calcium Metabolism Disorders', 'T006066', 'Calcium Metabolism Disorder'],
#   ['Calcium Metabolism Disorders', 'T006066', 'Disorder, Calcium Metabolism'],
#   ['Calcium Metabolism Disorders',
#    'T006066',
#    'Disorders, Calcium Metabolism']],
#  'D002137': [['Calculi', 'T006104', 'Calculi'],
#   ['Calculi', 'T006104', 'Calculus'],
#   ['Calculi', 'T366012', 'Biliary or Urinary Stones']],
#  'D002145': [['Callosities', 'T006133', 'Callosities'],
#   ['Callosities', 'T006133', 'Callosity'],
#   ['Callosities', 'T006132', 'Corns']],
#  'D002169': [['Campylobacter Infections',
#    'T006197',
#    'Campylobacter Infections'],
#   ['Campylobacter Infections', 'T000998641', 'Campylobacter Infection'],
#   ['Campylobacter Infections', 'T000998641', 'Infection, Campylobacter'],
#   ['Campylobacter Infections', 'T000908650', 'Campylobacteriosis'],
#   ['Campylobacter Infections', 'T000908650', 'Campylobacterioses'],
#   ['Campylobacter Infections', 'T006196', 'Infections, Campylobacter']],
#  'D002177': [['Candidiasis', 'T006219', 'Candidiasis'],
#   ['Candidiasis', 'T006219', 'Candidiases'],
#   ['Candidiasis', 'T001007097', 'Candida Infection'],
#   ['Candidiasis', 'T001007097', 'Candida Infections'],
#   ['Candidiasis', 'T001007097', 'Infection, Candida'],
#   ['Candidiasis', 'T006220', 'Moniliasis'],
#   ['Candidiasis', 'T006220', 'Moniliases']],
#  ...}

# %%
[[item.ui, item.name, item.concepts, item.tree_numbers] for item in curr if any(s for s in item.tree_numbers if any(xs in s for xs in treetops))]
# Out:
# []

# %%
#elem.get('ConceptPreferredTermYN', None)
if any(s for s in str(item.tree_numbers or 'EMPTY') if any(xs in s for xs in treetops))
[[item.ui, item.name, item.concepts, str(item.tree_numbers or 'EMPTY')] for item in curr ]
# Out:
# [['D000004',
#   'Abbreviations as Topic',
#   [Concept(ui='M0000004', name='Abbreviations as Topic', is_preferred=True, umls_ui=None, casn1_name=None, registry_num=None, scope_note='Works about shortened forms of written words or phrases used for brevity.\n    ', sem_types=None, terms=[Term(term_ui='T698652', string='Abbreviations as Topic', is_concept_preferred=True, is_record_preferred=True, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2007, 5, 31), thesaurus_list=['NLM (2008)'])]),
#    Concept(ui='M0511063', name='Acronyms as Topic', is_preferred=False, umls_ui=None, casn1_name=None, registry_num=None, scope_note=None, sem_types=None, terms=[Term(term_ui='T701041', string='Acronyms as Topic', is_concept_preferred=True, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2007, 6, 29), thesaurus_list=['NLM (2008)'])])],
#   "['L01.559.598.400.556.131']"]]

# %%
import csv
import os

data_dir = 'C:\\Users\\Richard.Geoghegan\\ML\\textmining\\dim_indication'
data_file='mesh_terms'
data_file = os.path.join(data_dir, data_file+'.csv')
data_file

with open(data_file, 'w', newline='') as f:
    wr = csv.writer(f, delimiter ='|')
    wr.writerows(res)

# %%
treetops = ['F','D']
matching = [s for s in l if any(xs in s for xs in matchers)]
any(s for s in l if any(xs in s for xs in matchers))
# Out:
# True

# %%
l=['D02.033.100.624.698.025', 'D05.033.755.624.698.025', 'D05.092.063.624.698.025']
[s.split('.')[0] for s in l]
# Out:
# ['D02', 'D05', 'D05']

# %%
D002292[0]
# Out:
# DescriptorRecord(ui='D002292', name='Carcinoma, Renal Cell', date_created=datetime.date(1984, 5, 29), date_revised=datetime.date(2021, 6, 30), pharm_actions=None, tree_numbers=['C04.557.470.200.025.390', 'C04.588.945.947.535.160', 'C12.050.351.937.820.535.160', 'C12.050.351.968.419.473.160', 'C12.200.758.820.750.160', 'C12.200.777.419.473.160', 'C12.900.820.535.160', 'C12.950.419.473.160', 'C12.950.983.535.160'], concepts=[Concept(ui='M0003442', name='Carcinoma, Renal Cell', is_preferred=True, umls_ui=None, casn1_name=None, registry_num=None, scope_note='A heterogeneous group of sporadic or hereditary carcinoma derived from cells of the KIDNEYS. There are several subtypes including the clear cells, the papillary, the chromophobe, the collecting duct, the spindle cells (sarcomatoid), or mixed cell-type carcinoma.\n    ', sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1999, 1, 1), thesaurus_list=['NLM (1985)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2019, 11, 22), thesaurus_list=['NLM (2021)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_prefer ...

# %%
dir(D002292[0].concepts)
D002292[0].tree_numbers
# Out:
# ['C04.557.470.200.025.390',
#  'C04.588.945.947.535.160',
#  'C12.050.351.937.820.535.160',
#  'C12.050.351.968.419.473.160',
#  'C12.200.758.820.750.160',
#  'C12.200.777.419.473.160',
#  'C12.900.820.535.160',
#  'C12.950.419.473.160',
#  'C12.950.983.535.160']

# %%
D002292[0].concepts
# Out:
# [Concept(ui='M0003442', name='Carcinoma, Renal Cell', is_preferred=True, umls_ui=None, casn1_name=None, registry_num=None, scope_note='A heterogeneous group of sporadic or hereditary carcinoma derived from cells of the KIDNEYS. There are several subtypes including the clear cells, the papillary, the chromophobe, the collecting duct, the spindle cells (sarcomatoid), or mixed cell-type carcinoma.\n    ', sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1999, 1, 1), thesaurus_list=['NLM (1985)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2019, 11, 22), thesaurus_list=['NLM (2021)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesau ...
#  Concept(ui='M0483487', name='Chromophobe Renal Cell Carcinoma', is_preferred=False, umls_ui=None, casn1_name=None, registry_num=None, scope_note=None, sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'ORD (2010)'])]),
#  Concept(ui='M0484518', name='Sarcomatoid Renal Cell Carcinoma', is_preferred=False, umls_ui=None, casn1_name=None, registry_num=None, scope_note=None, sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2008, 2, 1), thesaurus_list=['NLM (2009)'])]),
#  Concept(ui='M0483486', name='Papillary Renal Cell Carcinoma', is_preferred=False, umls_ui=None, casn1_name=None, registry_num=None, scope_note=None, sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 12, 13), thesaurus_list=['NLM (2012)', 'ORD (2010)'])]),
#  Concept(ui='M0483485', name='Clear Cell Renal Cell Carcinoma', is_preferred=False, umls_ui=None, casn1_name=None, registry_num=None, scope_note=None, sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='EPO', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='EPO', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 5, 11), thesaurus_list=['NLM (2006)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['OMIM (2013)', 'ORD (2010)', 'UNK (19XX)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None)]),
#  Concept(ui='M0483488', name='Collecting Duct Carcinoma (Kidney)', is_preferred=False, umls_ui=None, casn1_name=None, registry_num=None, scope_note=None, sem_types=None, terms=[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None), Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None)])]

# %%
[item for item in [item.terms for item in D002292[0].concepts]]
# Out:
# [[Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1999, 1, 1), thesaurus_list=['NLM (1985)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'OMIM (2013)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2019, 11, 22), thesaurus_list=['NLM (2021)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None)],
#  [Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'ORD (2010)'])],
#  [Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2008, 2, 1), thesaurus_list=['NLM (2009)'])],
#  [Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'ORD (2010)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2011, 11, 15), thesaurus_list=['OMIM (2013)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 12, 13), thesaurus_list=['NLM (2012)', 'ORD (2010)'])],
#  [Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)', 'ORD (2010)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='EPO', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='EPO', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 5, 11), thesaurus_list=['NLM (2006)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['UNK (19XX)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1984, 5, 29), thesaurus_list=['OMIM (2013)', 'ORD (2010)', 'UNK (19XX)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None)],
#  [Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2005, 4, 18), thesaurus_list=['NLM (2006)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(2010, 4, 21), thesaurus_list=['NLM (2011)', 'ORD (2010)']),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None),
#   Term(term_ui=None, string=None, is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None)]]

# %%
l=['aa','bb','cc']
a,b,c=l
print(a)
# Out:
# aa

# %%
l = [[item.ui, item.name, item.concepts, item.tree_numbers or 'EMPTY'] for item in curr ]
print('describe l: {}, {}'.format(type(l), len(l)))
# Out:
# describe l: <class 'list'>, 1

# %%
l[0]
# Out:
# ['D000001',
#  'Calcimycin',
#  [Concept(ui='M0000001', name='Calcimycin', is_preferred=True, umls_ui=None, casn1_name='4-Benzoxazolecarboxylic acid, 5-(methylamino)-2-((3,9,11-trimethyl-8-(1-methyl-2-oxo-2-(1H-pyrrol-2-yl)ethyl)-1,7-dioxaspiro(5.5)undec-2-yl)methyl)-, (6S-(6alpha(2S*,3S*),8beta(R*),9beta,11alpha))-', registry_num='37H9VM9WZL', scope_note='An ionophorous, polyether antibiotic from Streptomyces chartreusensis. It binds and transports CALCIUM and other divalent cations across membranes and uncouples oxidative phosphorylation while inhibiting ATPase of rat liver mitochondria. The substance is used mostly as a biochemical tool to study the role of divalent cations in various biological systems.\n    ', sem_types=None, terms=[Term(term_ui='T000002', string='Calcimycin', is_concept_preferred=True, is_record_preferred=True, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1999, 1, 1), thesaurus_list=['FDA SRS (2014)', 'NLM (1975)'])]),
#   Concept(ui='M0353609', name='A-23187', is_preferred=False, umls_ui=None, casn1_name=None, registry_num='0', scope_note=None, sem_types=None, terms=[Term(term_ui='T000001', string='A-23187', is_concept_preferred=True, is_record_preferred=False, is_permuted=False, lexical_tag='LAB', date_created=datetime.date(1990, 3, 8), thesaurus_list=['NLM (1991)']), Term(term_ui='T000001', string='A 23187', is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='LAB', date_created=None, thesaurus_list=None), Term(term_ui='T000004', string='A23187', is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='LAB', date_created=datetime.date(1974, 11, 11), thesaurus_list=['UNK (19XX)']), Term(term_ui='T000003', string='Antibiotic A23187', is_concept_preferred=False, is_record_preferred=False, is_permuted=False, lexical_tag='NON', date_created=datetime.date(1990, 3, 8), thesaurus_list=['NLM (1991)']), Term(term_ui='T000003', string='A23187, Antibiotic', is_concept_preferred=False, is_record_preferred=False, is_permuted=True, lexical_tag='NON', date_created=None, thesaurus_list=None)])],
#  ['D03.633.100.221.173']]

# %%
tree=['C04.557.465.625.600.380.080.335',
   'C04.557.470.670.380.080.335',
   'C04.557.580.625.600.380.080.335']

list(set(item.split('.')[0] for item in tree))
# Out:
# ['C04']

# %%
tree[0]
# Out:
# 'C04.557.465.625.600.380.080.335'
